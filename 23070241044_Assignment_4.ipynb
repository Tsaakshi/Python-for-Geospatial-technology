# %% [markdown]
# <a href="https://colab.research.google.com/github/Tsaakshi/Python-for-Geospatial-technology/blob/main/23070241044_Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2><b>Python for Geospatial Data Analysis</b></h2>
# <h3><b>Assignment 4</b></h3>
# <br>
# <h4><b>Name: Saakshi Tomar</b></h4>
# <h4><b>PRN: 23070241044</b></h4>
# <br>
# <br>

# %% [markdown]
# **Q1. Import necessary libraries**
#
# ---

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# **2. Reading Dataset**

# %%
dataset=pd.read_csv("nba.csv")

# %% [markdown]
# **3. Returns the first 8 rows of the Dataset**

# %%
dataset.head(8)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0
# 7            Gonzaga   2165160.0

# %% [markdown]
# **4. Returns the Last 8 rows of the Dataset.**

# %%
dataset.tail(8)
# Out:
#               Name       Team  Number Position   Age Height  Weight   College  \
# 450     Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0       NaN
# 451  Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0    Dayton
# 452     Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453   Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454      Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455   Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456    Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
# 457            NaN        NaN     NaN      NaN   NaN    NaN     NaN       NaN
#
#         Salary
# 450  2050000.0
# 451   981348.0
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %% [markdown]
# **5. Show brief Summary of the Dataset**

# %%
dataset.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
dataset.info
# Out:
# <bound method DataFrame.info of               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# ...

# %% [markdown]
# **6. Determine the dimensions or shape of a dataset.**

# %%
dataset.shape
# Out:
# (458, 9)

# %%
dataset.ndim
# Out:
# 2

# %% [markdown]
# **7. Use size function on Dataset, Observe the Difference between size and
# shape function.**

# %%
dataset.size
# Out:
# 4122

# %%
#my observation:
#.shape represents the rows and columns in the dataset.
#.size funtion represents the total number of data

# %% [markdown]
# **8. Show statistical summary of the Dataset.**

# %%
dataset.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# **9. select a random sample from Dataset**

# %%
dataset['Age'].sample(10)
# Out:
# 421    30.0
# 29     27.0
# 31     33.0
# 35     25.0
# 384    28.0
# 442    28.0
# 100    31.0
# 295    22.0
# 419    24.0
# 43     32.0
# Name: Age, dtype: float64

# %% [markdown]
# **10.Return the number of missing values in each column**

# %%
dataset.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %% [markdown]
# **11.Return number of unique elements.**

# %%
uniq_val=dataset['Age'].nunique()
print("The no. of unique values are: ",uniq_val)
# Out:
# The no. of unique values are:  22

# %% [markdown]
# **12.Use ( Value_counts ) Function on each Column and Observe the Result.**

# %%
#column 1: NAME
name_count=dataset["Name"].value_counts()
print("The Name counts are: ",name_count)
# Out:
# The Name counts are:  Avery Bradley       1
# Kyle Korver         1
# Al Horford          1
# Kirk Hinrich        1
# Tim Hardaway Jr.    1
#                    ..
# Eric Moreland       1
# Ben McLemore        1
# Kosta Koufos        1
# Rudy Gay            1
# Jeff Withey         1
# Name: Name, Length: 457, dtype: int64

# %%
#column 2 Team
team_count=dataset["Team"].value_counts()
print("The Team counts are: ",team_count)
# Out:
# The Team counts are:  New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
#column 3 Number
number_counts=dataset["Number"].value_counts()
print("The Number counts are: ",number_counts)
# Out:
# The Number counts are:  5.0     23
# 3.0     21
# 0.0     20
# 1.0     20
# 8.0     19
# 12.0    17
# 11.0    17
# 4.0     17
# 9.0     16
# 2.0     16
# 21.0    15
# 7.0     14
# 15.0    14
# 23.0    13
# 20.0    12
# 6.0     12
# 13.0    12
# 30.0    11
# 33.0    11
# 22.0    11
# 17.0    10
# 14.0    10
# 10.0    10
# 25.0    10
# 34.0     9
# 24.0     8
# 44.0     8
# 31.0     8
# 35.0     7
# 41.0     6
# 42.0     6
# 32.0     5
# 50.0     5
# 40.0     5
# 19.0     4
# 18.0     4
# 55.0     4
# 27.0     3
# 43.0     3
# 28.0     3
# 36.0     2
# 90.0     2
# 26.0     2
# 16.0     2
# 77.0     2
# 54.0     1
# 92.0     1
# 39.0     1
# 45.0     1
# 99.0     1
# 37.0     1
# 52.0     1
# 88.0     1
# Name: Number, dtype: int64

# %%
#column 3 Position
position_counts=dataset["Position"].value_counts()
print("The Position counts are: ",position_counts)
# Out:
# The Position counts are:  SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
#column 3 Age
age_count=dataset["Age"].value_counts
print("The Age counts are: ",age_count)
# Out:
# The Age counts are:  <bound method IndexOpsMixin.value_counts of 0      25.0
# 1      25.0
# 2      27.0
# 3      22.0
# 4      29.0
#        ...
# 453    26.0
# 454    24.0
# 455    26.0
# 456    26.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64>

# %%
#column 3 Height
height_count=dataset["Height"].value_counts
print("The Height counts are: ",height_count)
# Out:
# The Height counts are:  <bound method IndexOpsMixin.value_counts of 0       6-2
# 1       6-6
# 2       6-5
# 3       6-5
# 4      6-10
#        ...
# 453     6-3
# 454     6-1
# 455     7-3
# 456     7-0
# 457     NaN
# Name: Height, Length: 458, dtype: object>

# %%
#column 3 Weight
weight_count=dataset["Weight"].value_counts
print("The Weight counts are: ",weight_count)
# Out:
# The Weight counts are:  <bound method IndexOpsMixin.value_counts of 0      180.0
# 1      235.0
# 2      205.0
# 3      185.0
# 4      231.0
#        ...
# 453    203.0
# 454    179.0
# 455    256.0
# 456    231.0
# 457      NaN
# Name: Weight, Length: 458, dtype: float64>

# %%
#column 3 College
college_count=dataset["College"].value_counts
print("The College counts are: ",college_count)
# Out:
# The College counts are:  <bound method IndexOpsMixin.value_counts of 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
#              ...
# 453               Butler
# 454                  NaN
# 455                  NaN
# 456               Kansas
# 457                  NaN
# Name: College, Length: 458, dtype: object>

# %%
#column 3 Salary

salary_count=dataset["Salary"].value_counts
print("The Salary counts are: ",salary_count)
# Out:
# The Salary counts are:  <bound method IndexOpsMixin.value_counts of 0      7730337.0
# 1      6796117.0
# 2            NaN
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64>

# %% [markdown]
# **13.Drop unnecessary Columns From the Dataset**

# %%
dataset.drop(columns=["Weight"])
# Out:
#               Name            Team  Number Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# ..             ...             ...     ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0
# 457            NaN             NaN     NaN      NaN   NaN    NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# ...

# %% [markdown]
# **14.Determine number of unique element from the Dataset**

# %%
uniq_val2=dataset['Position'].nunique()
print("The no. of unique values are: ",uniq_val)
# Out:
# The no. of unique values are:  22

# %% [markdown]
# **15.Renaming the columns**

# %%
dataset.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
dataset.rename(columns = {"College":"Institute"})
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#              Institute     Salary
# 0                Texas  7730337.0
# ...

# %%
dataset.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
dataset.rename(columns = {"College":"Institute"}, inplace=True)

# %%
dataset.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#    Institute     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %% [markdown]
# **16.find the pairwise correlation of all columns in the dataframe also draw
# HeatMap For the same.**

# %%
dataset.corr()
# Out:
# <ipython-input-27-c187c74d1e71>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#           Number       Age    Weight    Salary
# Number  1.000000  0.028724  0.206921 -0.112386
# Age     0.028724  1.000000  0.087183  0.213459
# Weight  0.206921  0.087183  1.000000  0.138321
# Salary -0.112386  0.213459  0.138321  1.000000

# %%
sns.heatmap(dataset.corr())
# Out:
# <ipython-input-28-aa6664222663>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dataset.corr())
# <Axes: >

# %% [markdown]
# **17. find the pairwise correlation of any 3 columns in the dataframe also draw
# HeatMap For the same**

# %%
selected_col=dataset[4:7]

# %%
sel_col_corr=selected_col.corr()
# Out:
# <ipython-input-54-16c3a6615aac>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sel_col_corr=selected_col.corr()

# %%
print(sel_col_corr)
# Out:
#           Number       Age    Weight    Salary
# Number  1.000000 -0.084190  0.989016  0.570229
# Age    -0.084190  1.000000  0.064018  0.770561
# Weight  0.989016  0.064018  1.000000  0.685389
# Salary  0.570229  0.770561  0.685389  1.000000

# %%
import matplotlib.pyplot as plt
sns.heatmap(sel_col_corr,annot=True,cmap="magma")
plt.show()
